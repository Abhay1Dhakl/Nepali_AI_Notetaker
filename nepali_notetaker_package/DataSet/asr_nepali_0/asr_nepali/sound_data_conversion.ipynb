# %%
import os
import pandas as pd
from pydub import AudioSegment
from tqdm import tqdm
from glob import glob

# %%
tsv_path = 'transctipt0.tsv'
df = pd.read_csv(tsv_path, sep='\t', header = None)
print(df)
df.columns = ['0', '1', '2']
# Out:
#                  0      1                     2
# 0       4aa1fdca33  6a6d1      ००७ मिलको दूरीमा
# 1       86e521554a  1f680      ००७ मिलको दूरीमा
# 2       c96b2b1afb  e349f      ००७ मिलको दूरीमा
# 3       2f7ab41953  294d8  ०११ देखि काङ्ग्रेसको
# 4       c290e5124b  88901      ०१ सौर द्रव्यमान
# ...            ...    ...                   ...
# 157900  17c05d0bdb  06372      ह्रास हुन लाग्दछ
# 157901  2aa4a03723  79c24      ह्रास हुन लाग्दछ
# 157902  4cb59eba81  99866      ह्रास हुन लाग्दछ
# 157903  223df784fc  e7c22           ह्रास हुँदै
# 157904  fc3b1054b0  95358       ह्वाइटआई भनिन्छ
#
# [157905 rows x 3 columns]

# %%
audio_root_dir = r'd:\nepali_notetaker_project\nepali_notetaker_package\DataSet\asr_nepali_0\asr_nepali\data\07'

flac_path = glob(os.path.join(audio_root_dir, '**', '*.flac'), recursive=True)

# file_path = (os.path.splitext(os.path.basename(f))[0] for f in flac_path)

print(flac_path)
file_map = {os.path.splitext(os.path.basename(f))[0]: f for f in flac_path}
print(file_map)
# Add full path to dataframe
df['flac_path'] = df['0'].map(file_map)

df['file_id'] = df['flac_path'].apply(lambda x: os.path.splitext(os.path.basename(x))[0] if pd.notnull(x) else None)
# Drop missing entries
df = df[df['flac_path'].notnull()]
# Out:
# ['d:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0700709338.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0700b41a96.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0700bd8adf.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0701b56f9a.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0701ec06fa.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\07023f9135.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\07029d1f44.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0704067b8d.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0704728a1d.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\07049fbc7b.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0704d13d6e.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0704e7a293.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070550ce35.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070571f325.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070643c699.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\07064880c2.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070651e6ed.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0706cb1b9c.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0707bdd664.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070809d53a.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070890dc70.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0708bf89eb.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0708d0f7c7.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070952a4c7.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\07098559eb.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070a07b822.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070a25ebaa.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070a5d523f.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070a8b3614.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070a97478f.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070b90187e.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070be9f44f.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070bef4850.flac', 'd:\\nepali_notetaker_project\\nepali_n ...
# {'0700709338': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0700709338.flac', '0700b41a96': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0700b41a96.flac', '0700bd8adf': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0700bd8adf.flac', '0701b56f9a': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0701b56f9a.flac', '0701ec06fa': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0701ec06fa.flac', '07023f9135': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\07023f9135.flac', '07029d1f44': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\07029d1f44.flac', '0704067b8d': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0704067b8d.flac', '0704728a1d': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0704728a1d.flac', '07049fbc7b': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\07049fbc7b.flac', '0704d13d6e': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0704d13d6e.flac', '0704e7a293': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0704e7a293.flac', '070550ce35': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070550ce35.flac', '070571f325': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070571f325.flac', '070643c699': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070643c699.flac', '07064880c2': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\07064880c2.flac', '070651e6ed': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070651e6ed.flac', '0706cb1b9c': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0706cb1b9c.flac', '0707bdd664': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0707bdd664.flac', '070809d53a': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070809d53a.flac', '070890dc70': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070890dc70.flac', '0708bf89eb': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0708bf89eb.flac', '0708d0f7c7': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\0708d0f7c7.flac', '070952a4c7': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070952a4c7.flac', '07098559eb': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\07098559eb.flac', '070a07b822': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070a07b822.flac', '070a25ebaa': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070a25ebaa.flac', '070a5d523f': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070a5d523f.flac', '070a8b3614': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\07\\070a8b3614.flac', '070a97478f': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_0\\asr_nepali\\data\\0 ...

# %%
from pydub import AudioSegment
from tqdm import tqdm
import os

output_dir = os.path.join(audio_root_dir, 'processed_wav')
os.makedirs(output_dir, exist_ok=True)

wav_paths = []

for i, row in tqdm(df.iterrows(), total=len(df)):
    input_path = row['flac_path']
    file_id = row['file_id']
    output_path = os.path.join(output_dir, file_id + '.wav')

    try:
        # Load and convert to mono 16kHz
        sound = AudioSegment.from_file(input_path, format='flac')
        sound = sound.set_frame_rate(16000).set_channels(1)
        sound.export(output_path, format='wav')
        wav_paths.append(output_path)
    except Exception as e:
        print(f"❌ Failed to process {input_path}: {e}")
        wav_paths.append(None)

df['wav_path'] = wav_paths
df = df[df['wav_path'].notnull()]

# Save only required columns
final_df = df[['wav_path', '2']]
final_df
final_df.columns = ['path', '2']
final_df
final_df.to_csv('final_nepali_dataset_0_13.csv', index=False)

print("✅ Conversion complete. CSV saved as final_nepali_dataset.csv.")
# Out:
# 100%|██████████| 624/624 [02:01<00:00,  5.14it/s]
# ✅ Conversion complete. CSV saved as final_nepali_dataset.csv.
