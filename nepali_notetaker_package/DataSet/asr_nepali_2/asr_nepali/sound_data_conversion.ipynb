# %%
import os
import pandas as pd
from pydub import AudioSegment
from tqdm import tqdm
from glob import glob

# %%
tsv_path = 'transcript2.tsv'
df = pd.read_csv(tsv_path, sep='\t', header = None)
print(df)
df.columns = ['0', '1', '2']
# Out:
#                  0      1                     2
# 0       4aa1fdca33  6a6d1      ००७ मिलको दूरीमा
# 1       86e521554a  1f680      ००७ मिलको दूरीमा
# 2       c96b2b1afb  e349f      ००७ मिलको दूरीमा
# 3       2f7ab41953  294d8  ०११ देखि काङ्ग्रेसको
# 4       c290e5124b  88901      ०१ सौर द्रव्यमान
# ...            ...    ...                   ...
# 157900  17c05d0bdb  06372      ह्रास हुन लाग्दछ
# 157901  2aa4a03723  79c24      ह्रास हुन लाग्दछ
# 157902  4cb59eba81  99866      ह्रास हुन लाग्दछ
# 157903  223df784fc  e7c22           ह्रास हुँदै
# 157904  fc3b1054b0  95358       ह्वाइटआई भनिन्छ
#
# [157905 rows x 3 columns]

# %%
audio_root_dir = r'd:\nepali_notetaker_project\nepali_notetaker_package\DataSet\asr_nepali_2\asr_nepali\data\21'

flac_path = glob(os.path.join(audio_root_dir, '**', '*.flac'), recursive=True)

# file_path = (os.path.splitext(os.path.basename(f))[0] for f in flac_path)

print(flac_path)
file_map = {os.path.splitext(os.path.basename(f))[0]: f for f in flac_path}
print(file_map)
# Add full path to dataframe
df['flac_path'] = df['0'].map(file_map)

df['file_id'] = df['flac_path'].apply(lambda x: os.path.splitext(os.path.basename(x))[0] if pd.notnull(x) else None)
# Drop missing entries
df = df[df['flac_path'].notnull()]
# Out:
# ['d:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\21002a09ae.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\21006dc21c.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2101dd3979.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\21021d55a0.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\21027d0979.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2102c70767.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210307fabc.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210359efd5.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210380388a.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\21039bf9ba.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2103da5b53.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2103dffba6.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2103faffaf.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\21046808e9.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2104b351e4.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2104e9ef45.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\21055d77c7.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2107afad05.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210878ef5b.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2108c46a43.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210a394c4a.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210a4376fa.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210a5c1528.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210a6e4135.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210a8402b2.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210a9f3bf5.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210bc426b3.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210c0cfbf1.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210c2780cf.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210cf00dc9.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210d2ee3aa.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210d366030.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210d40e3d4.flac', 'd:\\nepali_notetaker_project\\nepali_n ...
# {'21002a09ae': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\21002a09ae.flac', '21006dc21c': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\21006dc21c.flac', '2101dd3979': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2101dd3979.flac', '21021d55a0': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\21021d55a0.flac', '21027d0979': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\21027d0979.flac', '2102c70767': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2102c70767.flac', '210307fabc': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210307fabc.flac', '210359efd5': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210359efd5.flac', '210380388a': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210380388a.flac', '21039bf9ba': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\21039bf9ba.flac', '2103da5b53': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2103da5b53.flac', '2103dffba6': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2103dffba6.flac', '2103faffaf': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2103faffaf.flac', '21046808e9': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\21046808e9.flac', '2104b351e4': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2104b351e4.flac', '2104e9ef45': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2104e9ef45.flac', '21055d77c7': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\21055d77c7.flac', '2107afad05': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2107afad05.flac', '210878ef5b': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210878ef5b.flac', '2108c46a43': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\2108c46a43.flac', '210a394c4a': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210a394c4a.flac', '210a4376fa': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210a4376fa.flac', '210a5c1528': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210a5c1528.flac', '210a6e4135': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210a6e4135.flac', '210a8402b2': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210a8402b2.flac', '210a9f3bf5': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210a9f3bf5.flac', '210bc426b3': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210bc426b3.flac', '210c0cfbf1': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210c0cfbf1.flac', '210c2780cf': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\21\\210c2780cf.flac', '210cf00dc9': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\2 ...

# %%
from pydub import AudioSegment
from tqdm import tqdm
import os

output_dir = os.path.join(audio_root_dir, 'processed_wav')
os.makedirs(output_dir, exist_ok=True)

wav_paths = []

for i, row in tqdm(df.iterrows(), total=len(df)):
    input_path = row['flac_path']
    file_id = row['file_id']
    output_path = os.path.join(output_dir, file_id + '.wav')
    try:
        # Load and convert to mono 16kHz
        sound = AudioSegment.from_file(input_path, format='flac')
        sound = sound.set_frame_rate(16000).set_channels(1)
        sound.export(output_path, format='wav')
        wav_paths.append(output_path)
    except Exception as e:
        print(f"Failed to process {input_path}: {e}")
        wav_paths.append(None)

df['wav_path'] = wav_paths
df = df[df['wav_path'].notnull()]

# Save only required columns
final_df = df[['wav_path', '2']]
final_df
final_df.columns = ['path', '2']
final_df
final_df.to_csv('final_nepali_dataset_2_8.csv', index=False)

print("✅ Conversion complete. CSV saved as final_nepali_dataset.csv.")
# Out:
# 100%|██████████| 639/639 [02:07<00:00,  5.00it/s]
# ✅ Conversion complete. CSV saved as final_nepali_dataset.csv.
