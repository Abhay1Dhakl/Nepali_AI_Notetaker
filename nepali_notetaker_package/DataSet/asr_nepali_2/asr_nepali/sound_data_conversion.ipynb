# %%
import os
import pandas as pd
from pydub import AudioSegment
from tqdm import tqdm
from glob import glob

# %%
tsv_path = 'transcript2.tsv'
df = pd.read_csv(tsv_path, sep='\t', header = None)
print(df)
df.columns = ['0', '1', '2']
# Out:
#                  0      1                     2
# 0       4aa1fdca33  6a6d1      ००७ मिलको दूरीमा
# 1       86e521554a  1f680      ००७ मिलको दूरीमा
# 2       c96b2b1afb  e349f      ००७ मिलको दूरीमा
# 3       2f7ab41953  294d8  ०११ देखि काङ्ग्रेसको
# 4       c290e5124b  88901      ०१ सौर द्रव्यमान
# ...            ...    ...                   ...
# 157900  17c05d0bdb  06372      ह्रास हुन लाग्दछ
# 157901  2aa4a03723  79c24      ह्रास हुन लाग्दछ
# 157902  4cb59eba81  99866      ह्रास हुन लाग्दछ
# 157903  223df784fc  e7c22           ह्रास हुँदै
# 157904  fc3b1054b0  95358       ह्वाइटआई भनिन्छ
#
# [157905 rows x 3 columns]

# %%
audio_root_dir = r'd:\nepali_notetaker_project\nepali_notetaker_package\DataSet\asr_nepali_2\asr_nepali\data\29'

flac_path = glob(os.path.join(audio_root_dir, '**', '*.flac'), recursive=True)

# file_path = (os.path.splitext(os.path.basename(f))[0] for f in flac_path)

print(flac_path)
file_map = {os.path.splitext(os.path.basename(f))[0]: f for f in flac_path}
print(file_map)
# Add full path to dataframe
df['flac_path'] = df['0'].map(file_map)

df['file_id'] = df['flac_path'].apply(lambda x: os.path.splitext(os.path.basename(x))[0] if pd.notnull(x) else None)
# Drop missing entries
df = df[df['flac_path'].notnull()]
# Out:
# ['d:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2900082bdc.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\29004b40be.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2900b72f0c.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290125ee42.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290181879e.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2901ee5efe.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2902453228.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2902554a32.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290261ea34.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\29027c934c.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2903149fb9.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\29032a10a9.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2903cad16e.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2905c91a20.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2905fa6d05.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\29061ba514.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290673f02b.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290812f167.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2908aa4317.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290ab31860.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290ad3ca69.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290b02e366.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290c958a8d.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290ca3ce18.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290cabf7b7.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290d49597f.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290e839714.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290f2eba1e.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290f38cff6.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290faf6c45.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290fd0fe23.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\29112be1f2.flac', 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2911f5c82e.flac', 'd:\\nepali_notetaker_project\\nepali_n ...
# {'2900082bdc': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2900082bdc.flac', '29004b40be': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\29004b40be.flac', '2900b72f0c': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2900b72f0c.flac', '290125ee42': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290125ee42.flac', '290181879e': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290181879e.flac', '2901ee5efe': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2901ee5efe.flac', '2902453228': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2902453228.flac', '2902554a32': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2902554a32.flac', '290261ea34': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290261ea34.flac', '29027c934c': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\29027c934c.flac', '2903149fb9': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2903149fb9.flac', '29032a10a9': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\29032a10a9.flac', '2903cad16e': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2903cad16e.flac', '2905c91a20': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2905c91a20.flac', '2905fa6d05': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2905fa6d05.flac', '29061ba514': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\29061ba514.flac', '290673f02b': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290673f02b.flac', '290812f167': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290812f167.flac', '2908aa4317': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\2908aa4317.flac', '290ab31860': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290ab31860.flac', '290ad3ca69': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290ad3ca69.flac', '290b02e366': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290b02e366.flac', '290c958a8d': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290c958a8d.flac', '290ca3ce18': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290ca3ce18.flac', '290cabf7b7': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290cabf7b7.flac', '290d49597f': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290d49597f.flac', '290e839714': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290e839714.flac', '290f2eba1e': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290f2eba1e.flac', '290f38cff6': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\29\\290f38cff6.flac', '290faf6c45': 'd:\\nepali_notetaker_project\\nepali_notetaker_package\\DataSet\\asr_nepali_2\\asr_nepali\\data\\2 ...

# %%
from pydub import AudioSegment
from tqdm import tqdm
import os

output_dir = os.path.join(audio_root_dir, 'processed_wav')
os.makedirs(output_dir, exist_ok=True)

wav_paths = []

for i, row in tqdm(df.iterrows(), total=len(df)):
    input_path = row['flac_path']
    file_id = row['file_id']
    output_path = os.path.join(output_dir, file_id + '.wav')
    try:
        # Load and convert to mono 16kHz
        sound = AudioSegment.from_file(input_path, format='flac')
        sound = sound.set_frame_rate(16000).set_channels(1)
        sound.export(output_path, format='wav')
        wav_paths.append(output_path)
    except Exception as e:
        print(f"Failed to process {input_path}: {e}")
        wav_paths.append(None)

df['wav_path'] = wav_paths
df = df[df['wav_path'].notnull()]

# Save only required columns
final_df = df[['wav_path', '2']]
final_df
final_df.columns = ['path', '2']
final_df
final_df.to_csv('final_nepali_dataset_2_16.csv', index=False)

print("✅ Conversion complete. CSV saved as final_nepali_dataset.csv.")
# Out:
# 100%|██████████| 643/643 [02:40<00:00,  4.02it/s]
# ✅ Conversion complete. CSV saved as final_nepali_dataset.csv.
